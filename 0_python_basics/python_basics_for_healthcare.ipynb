# %% [markdown]
# # Python Basics for Healthcare Professionals
#
# Welcome to your first step in learning Python for healthcare and life sciences! This notebook covers the essentials: variables, data types, operators, control flow, functions, and more. Updated for 2026, it includes modern Python features and best practices.

# %% [markdown]
# ## 1. Variables, Data Types, and Operators
# Learn how to store and manipulate data in Python.

# %%
# Variables and data types
patient_name: str = 'John Doe'
age: int = 45
height_cm: float = 170.5
is_patient: bool = True

print(f'Patient Name: {patient_name}, Age: {age}, Height: {height_cm} cm, Is patient: {is_patient}')

# Arithmetic and logical operators
bmi = 70 / (1.7 ** 2)
is_senior = age > 60
print(f'BMI: {bmi:.2f}, Is senior: {is_senior}')

# %% [markdown]
# ## 2. Control Flow: Conditionals and Loops
# Control the flow of your program using `if`, `else`, and loops.

# %%
bp = 150  # blood pressure
if bp > 140:

# For loop: List of patient ages
ages = [34, 67, 29, 56]
for a in ages:

# While loop: Counting pills
pills = 5
while pills > 0:

# %% [markdown]
# ## 3. Functions and Modules
# Organize code and avoid repetition. Use built-in and custom modules.

# %%
def calculate_bmi(weight_kg: float, height_m: float) -> float:
bmi = calculate_bmi(70, 1.7)
print(f'BMI: {bmi:.2f}')

import math
print(f'Square root of 16 is {math.sqrt(16)}')

# %% [markdown]
# ## 4. Data Structures: Lists, Tuples, Dictionaries, Sets
# Store and organize healthcare data efficiently.

# %%
patients = ['Alice', 'Bob', 'Charlie']
patient_info = ('Alice', 30)
patient_record = {'name': 'Alice', 'age': 30, 'bp': 120}
unique_ages = set([34, 67, 29, 56, 34, 29])
print(f'First patient: {patients[0]}')
print(f'Patient info: {patient_info}')
print(f'Patient name: {patient_record['name']}')
print(f'Unique ages: {unique_ages}')

# %% [markdown]
# ## 5. Exception Handling and Debugging
# Handle errors gracefully and debug your code.

# %%
try:

def divide(a: float, b: float) -> float:
divide(10, 2)
divide(10, 0)

# %% [markdown]
# ## 6. Writing Readable Python Code (2026 Best Practices)
# Use comments, docstrings, type hints, and modern conventions.

# %%
def calculate_area(radius: float) -> float:
circle_area = calculate_area(5)
print(f'Area of circle: {circle_area}')
# Use meaningful variable names
patient_age = 45
patient_name = 'Alice'
print(f'Patient: {patient_name}, Age: {patient_age}')

# %% [markdown]
# ## 7. Exercises
# Try these problems to reinforce your learning.

# %%
# 1. Write a function to check if a patient is hypertensive (bp > 140)
def is_hypertensive(bp: int) -> bool:
print(is_hypertensive(150))  # Should print True
print(is_hypertensive(120))  # Should print False

# 2. Create a list of patient records and print those with age > 40
records = [
for r in records:
